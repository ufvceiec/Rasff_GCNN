# %%
##Se junta el dataset con todos los valores + el nuevo. Cambiar la ruta y nombre del dataset nuevo y ejecutar. 
##Se eliminan los valores duplicados.

# %%
import numpy as np
import pandas as pd

# %%
#Viejo dataset
data = pd.read_csv('./full_RASFF_DATA_16092019.csv', sep=';', 
                   header=0, index_col = 0)
old = data

# %%
#Nuevo dataset
data = pd.read_csv('./new_RASFF_DATA.csv', sep='\t', 
                   header=0, index_col = 0)
new = data

# %%
#Unión de ambos datasets
df = pd.concat([new,old])

# %%
#Tratamiento de formato del nuevo dataset.

#Borramos duplicados
df = df.drop_duplicates(subset='REF')

#Eliminamos registros no válidos.
df = df.dropna(how='all')
df = df.dropna(subset = ['DATE_CASE'])
data = data.fillna(" ")

#Ordenar los registros por fecha .
df['DATE_CASE'] = pd.to_datetime(df['DATE_CASE'],  errors='coerce', dayfirst=True, format = '%d/%m/%Y')
df= df.sort_values(by='DATE_CASE',ascending=False)
df = df.reset_index(drop = True)
#df = df.rename(columns={"COUNT_ORIGEN": "ORIG_COUNTRY", "COUNT_DESTIN": "DESTIN_COUNTRY", "COUNT_CONCERN": "CONCERN_COUNTRY"})
df = df[df.CLASSIF != ' ']

#Poner estos campos en lowercase.
df ['CLASSIF'] = df ['CLASSIF'].str.lower()
df ['PROD_CAT'] = df ['PROD_CAT'].str.lower()
df ['TYPE'] = df ['TYPE'].str.lower()
df ['RISK_DECISION'] = df ['RISK_DECISION'].str.lower()
df ['ACTION_TAKEN'] = df ['ACTION_TAKEN'].str.lower()
df ['DISTRIBUTION_STAT'] = df ['DISTRIBUTION_STAT'].str.lower()
df ['PRODUCT'] = df ['PRODUCT'].str.lower()
df ['HAZARDS'] = df ['HAZARDS'].str.lower()
df ['HAZARDS_CAT'] = df ['HAZARDS_CAT'].str.lower()

#Debug
display(df)
print(df.dtypes)
# Out:
#                          CLASSIF  DATE_CASE        REF          NOT_COUNTRY  \
# 0                          alert 2021-01-15  2021.0219                Italy
# 1               border rejection 2021-01-15  2021.0220             Bulgaria
# 2                          alert 2021-01-15  2021.0214            Lithuania
# 3      information for follow-up 2021-01-15  2021.0216               France
# 4               border rejection 2021-01-15  2021.0211              Belgium
# ...                          ...        ...        ...                  ...
# 61511                      alert 1980-04-10    1980.04              Belgium
# 61512                      alert 1980-04-10    1980.03              Belgium
# 61513                      alert 1980-03-24    1980.02       United Kingdom
# 61514                      alert 1980-01-26    1980.01               France
# 61515                      alert 1979-09-15    1979.01  Commission Services
#
#                                                   SUBJET  \
# 0      glass fragments in organic vegetable sauce fro...
# 1      unauthorised substance chlorpyrifos-methyl (0....
# 2      Salmonella enterica ser. Enteritidis (presence...
# 3      Listeria monocytogenes (< 10 CFU/g) in frozen ...
# 4      cypermethrin (1.6 mg/kg - ppm) in peppers from...
# ...                                                  ...
# 61511  too high content of total volatile basic nitro...
# 61512                 Staphylococcus in Shrimps - frozen
# 61513                   bulging packaging of Corned beef
# 61514  too high content of total volatile basic nitro...
# 61515  too high content of total volatile basic nitro...
#
#                                           PROD_CAT  TYPE RISK_DECISION  \
# 0             soups, broths, sauces and condiments  food       serious
# 1                            fruits and vegetables  food     undecided
# 2           poultry meat and poultry meat products  food       serious
# 3                       prepared dishes and snacks  food   not serious
# 4                            fruits and vegetables  food       serious
# ...                                            ...   ...           ...
# 61511  meat and meat products (other than poultry)  food     undecided
# 61512             crustaceans and products thereof  food     undecided
# 61513  meat and meat products (other than poultry)  food     undecided
# 61514                       fish and fish products  food     undecided
# 61515   molluscs and products thereof - (obsolete)  food     undecided
#
#                 ACTION_TAKEN                                DISTRIBUTION_STAT  \
# 0      recall from consumers           distribution to other member countries
# 1                destruction           product not (yet) placed on the market
# 2                destruction           no distribution from notifying country
# 3       detained by operator  information on distribution not (yet) available
# 4      informing authorities           product not (yet) placed on the market
# ...                      ...                                              ...
# 61511
# 61512
# 61513
# 61514
# 61515
#
#                                            PRODUCT  \
# 0                          organic vegetable sauce
# 1                                           lemons
# 2                   frozen chicken broiler fillets
# 3      frozen pre-cooked chicken curry cassolettes
# 4                                          peppers
# ...                                            ...
# 61511                          frogs legs - frozen
# 61512                             shrimps - frozen
# 61513                                  corned beef
# 61514                         skate wings - frozen
# 61515                            calamaris damaged
#
#                                                  HAZARDS  \
# 0                                        glass fragments
# 1             unauthorised substance chlorpyrifos-methyl
# 2                   salmonella enterica ser. enteritidis
# 3                                 listeria monocytogenes
# 4                                           cypermethrin
# ...                                                  ...
# 61511  too high content of total volatile basic nitrogen
# 61512                                     staphylococcus
# 61513                                  bulging packaging
# 61514  too high content of total volatile basic nitrogen
# 61515  too high content of total volatile basic nitrogen
#
#                            HAZARDS_CAT    COUNT_ORIGEN COUNT_DESTIN  \
# 0                       foreign bodies           Italy  Italy,Malta
# 1                   pesticide residues          Turkey          NaN
# 2           pathogenic micro-organisms          Poland    Lithuania
# 3       microbial contaminants (other)           Spain          NaN
# 4                   pesticide residues          Uganda          NaN
# ...                                ...             ...          ...
# 61511             organoleptic aspects        Malaysia
# 61512   microbial contaminants (other)        Malaysia
# 61513  packaging defective / incorrect  United Kingdom
# 61514             organoleptic aspects    South Africa
# 61515             organoleptic aspects  unknown origin
#
#              COUNT_CONCERN   NUMBER
# 0                      NaN      NaN
# 1                 Bulgaria      NaN
# 2                      NaN      NaN
# 3                   France      NaN
# 4                  Belgium      NaN
# ...                    ...      ...
# 61511              Belgium  56487.0
# 61512              Belgium  56488.0
# 61513                       56489.0
# 61514               France  56490.0
# 61515  Commission Services  56491.0
#
# [61516 rows x 17 columns]
# CLASSIF                      object
# DATE_CASE            datetime64[ns]
# REF                          object
# NOT_COUNTRY                  object
# SUBJET                       object
# PROD_CAT                     object
# TYPE                         object
# RISK_DECISION                object
# ACTION_TAKEN                 object
# DISTRIBUTION_STAT            object
# PRODUCT                      object
# HAZARDS                      object
# HAZARDS_CAT                  object
# COUNT_ORIGEN                 object
# COUNT_DESTIN                 object
# COUNT_CONCERN                object
# NUMBER                      float64
# dtype: object

# %%
#Creamos las alertas desacopladas

display(data['HAZARDS_CAT'].str.split(',').explode())
# Out:
# NUMBER
# 1.0                        foreign bodies
# 3.0                    pesticide residues
# 5.0                    pesticide residues
# 7.0                    pesticide residues
# 9.0            pathogenic micro-organisms
#                         ...
# 20122.0        pathogenic micro-organisms
# 20124.0    microbial contaminants (other)
# 20126.0        pathogenic micro-organisms
# 20128.0                pesticide residues
# 20130.0                        mycotoxins
# Name: HAZARDS_CAT, Length: 23587, dtype: object

# %%
#Dataset que genera.
df.to_csv('./full_RASFF_DATA.csv', sep=';')
